# %% [markdown]
# <a href="https://colab.research.google.com/github/KartikMantri/U-Kan-repo/blob/main/DualDecoder_UNet_SpatialAttention_Containment_REFUGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dual-Decoder U-Net (Y-Net) + Spatial Attention (CBAM) + Containment Loss — REFUGE (3-class)
#
# **Base model:** one *shared* U-Net encoder + bottleneck feeding **two parallel decoders**
# - **Disc head:** background vs whole optic disc (disc+cup)
# - **Cup head:** background vs optic cup
#
# **This version adds:**
# 1. **Spatial attention (CBAM)** inside **both decoder pipelines** — after every decoder stage,
#    an avg+max channel-pool -> conv -> sigmoid produces a spatial mask that emphasises the
#    relevant (disc/cup) region and suppresses background. (As used in SA-U-KAN.)
# 2. **Containment loss** — a differentiable penalty pushing the predicted cup to lie **inside**
#    the predicted disc (cup ⊆ disc).
#
# *No cross-attention here — this is the clean standalone spatial-attention variant.*
# Metrics for the **two pipelines are reported separately** for train, validation and test,
# plus a **fused 3-class** score. Target: mean disc+cup Dice ≥ 0.90.

# %%
# ============================================================
# CELL 0 — Environment setup
# Imports, fixed seeds for reproducibility, device, and global config.
# ============================================================
# !pip install -q albumentations

import os, cv2, glob, random, math
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import albumentations as A
from albumentations.pytorch import ToTensorV2
from scipy import ndimage

# --- reproducibility ---
SEED = 42
random.seed(SEED); np.random.seed(SEED)
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

DEVICE    = torch.device("cuda" if torch.cuda.is_available() else "cpu")
IMG_SIZE  = 256

# writable output folder: /kaggle/working on Kaggle, else current dir (e.g. Colab /content)
OUT_DIR   = "/kaggle/working" if os.path.isdir("/kaggle/working") else "."
os.makedirs(OUT_DIR, exist_ok=True)
SAVE_PATH = os.path.join(OUT_DIR, "best_dualunet_sa.pth")
print("Device:", DEVICE, "| IMG_SIZE:", IMG_SIZE, "| OUT_DIR:", OUT_DIR)
# Out:
# Device: cuda | IMG_SIZE: 256 | OUT_DIR: .

# %%
# ============================================================
# CELL 1 — Get the REFUGE dataset (auto-download)
# Downloads glaucoma-datasets via kagglehub and points DATA_ROOT at REFUGE.
# (Turn ON Internet: Settings -> Internet.) Uses an attached copy if present.
# ============================================================
# !pip install -q kagglehub

import glob, os
DATA_ROOT = None
_cands = glob.glob("/kaggle/input/**/REFUGE", recursive=True)
if _cands:
    DATA_ROOT = _cands[0]
    print("Found attached dataset.")
else:
    import kagglehub
    _path = kagglehub.dataset_download("arnavjain1/glaucoma-datasets")
    print("Downloaded to:", _path)
    _cands = glob.glob(os.path.join(_path, "**", "REFUGE"), recursive=True)
    DATA_ROOT = _cands[0] if _cands else os.path.join(_path, "REFUGE")

print("Using DATA_ROOT:", DATA_ROOT)
assert os.path.isdir(DATA_ROOT), "REFUGE folder not found - check the dataset / Internet setting"
# Out:
# Downloading to /root/.cache/kagglehub/datasets/arnavjain1/glaucoma-datasets/4.archive...
# 100%|██████████| 5.55G/5.55G [00:52<00:00, 113MB/s]
# Extracting files...
# Downloaded to: /root/.cache/kagglehub/datasets/arnavjain1/glaucoma-datasets/versions/4
# Using DATA_ROOT: /root/.cache/kagglehub/datasets/arnavjain1/glaucoma-datasets/versions/4/REFUGE

# %%
# ---- inspect REFUGE folder structure ----
import os
print("DATA_ROOT:", DATA_ROOT)
print("\nInside DATA_ROOT:", os.listdir(DATA_ROOT))
for split in ["train", "val", "test"]:
    p = os.path.join(DATA_ROOT, split)
    if os.path.isdir(p):
        print(f"\n{split}/ ->", os.listdir(p))
        # show how many files are in the cropped folders we actually use
        for sub in ["Images_Cropped", "Masks_Cropped"]:
            q = os.path.join(p, sub)
            if os.path.isdir(q):
                print(f"   {sub}: {len(os.listdir(q))} files  (e.g. {os.listdir(q)[:2]})")
# Out:
# DATA_ROOT: /root/.cache/kagglehub/datasets/arnavjain1/glaucoma-datasets/versions/4/REFUGE
#
# Inside DATA_ROOT: ['test', 'val', 'Masks_Square', 'Images_Square', 'train']
#
# train/ -> ['index.json', 'illustrations', 'Masks', 'Images', 'Images_Cropped', 'gts', 'Masks_Cropped']
#    Images_Cropped: 400 files  (e.g. ['n0022.jpg', 'n0351.jpg'])
#    Masks_Cropped: 400 files  (e.g. ['n0185.png', 'n0041.png'])
#
# val/ -> ['index.json', 'Masks', 'Images', 'Images_Cropped', 'gts', 'Masks_Cropped']
#    Images_Cropped: 400 files  (e.g. ['V0125.jpg', 'V0264.jpg'])
#    Masks_Cropped: 400 files  (e.g. ['V0292.png', 'V0308.png'])
#
# test/ -> ['index.json', 'Masks', 'Images', 'Images_Cropped', 'gts', 'Masks_Cropped']
#    Images_Cropped: 400 files  (e.g. ['T0003.jpg', 'T0220.jpg'])
#    Masks_Cropped: 400 files  (e.g. ['T0090.png', 'T0193.png'])

# %%
# ============================================================
# CELL 2 — Base REFUGE dataset (raw 3-class masks)
# Mask pixel values: 0 = background, 1 = optic disc (rim), 2 = optic cup
# ============================================================
class REFUGEDataset(Dataset):
    def __init__(self, img_dir, mask_dir, transform=None):
        self.img_dir, self.mask_dir, self.transform = img_dir, mask_dir, transform
        self.filenames = []
        for f in sorted(os.listdir(img_dir)):
            base = os.path.splitext(f)[0]
            mp = os.path.join(mask_dir, base + ".png")
            if os.path.exists(mp):
                self.filenames.append((f, base + ".png"))

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):
        img_name, mask_name = self.filenames[idx]
        image = cv2.cvtColor(cv2.imread(os.path.join(self.img_dir, img_name)), cv2.COLOR_BGR2RGB)
        mask  = cv2.imread(os.path.join(self.mask_dir, mask_name), cv2.IMREAD_UNCHANGED)
        if self.transform:
            aug = self.transform(image=image, mask=mask)
            image, mask = aug["image"], aug["mask"]
        return image, mask.long()

# %%
# ============================================================
# CELL 3 — Augmentations + base datasets
# ============================================================
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5), A.VerticalFlip(p=0.3),
    A.Rotate(limit=20, p=0.5),
    A.RandomBrightnessContrast(0.2, 0.2, p=0.5),
    A.Normalize(mean=(0.485,0.456,0.406), std=(0.229,0.224,0.225)),
    ToTensorV2(),
])
val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=(0.485,0.456,0.406), std=(0.229,0.224,0.225)),
    ToTensorV2(),
])

train_ds = REFUGEDataset(f"{DATA_ROOT}/train/Images_Cropped", f"{DATA_ROOT}/train/Masks_Cropped", train_transform)
val_ds   = REFUGEDataset(f"{DATA_ROOT}/val/Images_Cropped",   f"{DATA_ROOT}/val/Masks_Cropped",   val_transform)
test_ds  = REFUGEDataset(f"{DATA_ROOT}/test/Images_Cropped",  f"{DATA_ROOT}/test/Masks_Cropped",  val_transform)

print("Train:", len(train_ds), "Val:", len(val_ds), "Test:", len(test_ds))
# Out:
# Train: 400 Val: 400 Test: 400

# %%
# ============================================================
# CELL 4 — Dual-task wrapper: split 3-class mask into TWO binary masks
#   disc_m : 1 where (mask > 0)   == whole optic disc (disc+cup)   [Pipeline 1]
#   cup_m  : 1 where (mask == 2)  == optic cup only                [Pipeline 2]
# ============================================================
class DualTaskDataset(Dataset):
    def __init__(self, base_dataset):
        self.base = base_dataset
    def __len__(self):
        return len(self.base)
    def __getitem__(self, idx):
        image, mask3 = self.base[idx]
        disc_m = (mask3 > 0).long()
        cup_m  = (mask3 == 2).long()
        return image, disc_m, cup_m

BATCH_SIZE = 8      # 256 -> 8

train_ds_dual = DualTaskDataset(train_ds)
val_ds_dual   = DualTaskDataset(val_ds)
test_ds_dual  = DualTaskDataset(test_ds)

train_loader = DataLoader(train_ds_dual, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_ds_dual,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_ds_dual,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

imgs, disc_m, cup_m = next(iter(train_loader))
print("img:", imgs.shape, "| disc:", disc_m.shape, torch.unique(disc_m).tolist(),
      "| cup:", cup_m.shape, torch.unique(cup_m).tolist())
# Out:
# img: torch.Size([8, 3, 256, 256]) | disc: torch.Size([8, 256, 256]) [0, 1] | cup: torch.Size([8, 256, 256]) [0, 1]

# %%
# ============================================================
# CELL 5 — Metrics (per binary head) + dual evaluation helper
# Reported loss includes the containment term (CELL 6) for train/val/test consistency.
# ============================================================
@torch.no_grad()
def compute_all_metrics(logits, targets, num_classes=2, smooth=1e-6):
    preds = torch.argmax(logits, dim=1)
    m = {k: [] for k in ["dice","iou","precision","recall","f1"]}
    for c in range(num_classes):
        pred_c, target_c = (preds == c), (targets == c)
        tp = (pred_c & target_c).sum().float()
        fp = (pred_c & ~target_c).sum().float()
        fn = (~pred_c & target_c).sum().float()
        precision = (tp+smooth)/(tp+fp+smooth)
        recall    = (tp+smooth)/(tp+fn+smooth)
        m["dice"].append(((2*tp+smooth)/(2*tp+fp+fn+smooth)).item())
        m["iou"].append(((tp+smooth)/(tp+fp+fn+smooth)).item())
        m["precision"].append(precision.item())
        m["recall"].append(recall.item())
        m["f1"].append(((2*precision*recall)/(precision+recall+smooth)).item())
    m["accuracy"] = (preds == targets).float().mean().item()
    return m

@torch.no_grad()
def evaluate_dual(model, loader, criterion, device=DEVICE):
    """Return (avg_loss, disc_metrics, cup_metrics) — pipelines scored separately."""
    model.eval()
    running_loss = 0.0
    keys = ["dice","iou","precision","recall","f1"]
    agg_disc = {k: np.zeros(2) for k in keys}; agg_disc["accuracy"] = 0.0
    agg_cup  = {k: np.zeros(2) for k in keys}; agg_cup["accuracy"]  = 0.0
    n_batches = 0
    for imgs, disc_m, cup_m in loader:
        imgs, disc_m, cup_m = imgs.to(device), disc_m.to(device), cup_m.to(device)
        out_disc, out_cup = model(imgs)
        loss = (criterion(out_disc, disc_m) + criterion(out_cup, cup_m)
                + LAMBDA_CONTAIN * containment_loss(out_disc, out_cup))
        running_loss += loss.item() * imgs.size(0)
        md_ = compute_all_metrics(out_disc, disc_m)
        mc_ = compute_all_metrics(out_cup,  cup_m)
        for k in keys:
            agg_disc[k] += np.array(md_[k]); agg_cup[k] += np.array(mc_[k])
        agg_disc["accuracy"] += md_["accuracy"]; agg_cup["accuracy"] += mc_["accuracy"]
        n_batches += 1
    for k in keys:
        agg_disc[k] /= n_batches; agg_cup[k] /= n_batches
    agg_disc["accuracy"] /= n_batches; agg_cup["accuracy"] /= n_batches
    return running_loss/len(loader.dataset), agg_disc, agg_cup

# %%
# ============================================================
# CELL 6 — Losses
# DiceLoss: soft multi-class Dice. CombinedLoss: 0.5*CE + 0.5*Dice (per head).
# containment_loss: differentiable penalty so the CUP stays INSIDE the DISC.
# ============================================================
class DiceLoss(nn.Module):
    def __init__(self, num_classes=2, smooth=1e-6):
        super().__init__()
        self.num_classes, self.smooth = num_classes, smooth
    def forward(self, logits, targets):
        probs = F.softmax(logits, dim=1)
        targets_oh = F.one_hot(targets, self.num_classes).permute(0,3,1,2).float()
        inter = torch.sum(probs*targets_oh, (0,2,3))
        union = torch.sum(probs+targets_oh, (0,2,3))
        return 1 - ((2*inter+self.smooth)/(union+self.smooth)).mean()

class CombinedLoss(nn.Module):
    def __init__(self, num_classes=2):
        super().__init__()
        self.ce = nn.CrossEntropyLoss()
        self.dice = DiceLoss(num_classes)
    def forward(self, logits, targets):
        return 0.5*self.ce(logits, targets) + 0.5*self.dice(logits, targets)

# ---- containment: penalise cup probability lying OUTSIDE the disc (cup ⊆ disc) ----
LAMBDA_CONTAIN = 0.5
def containment_loss(out_disc, out_cup):
    p_disc = F.softmax(out_disc, dim=1)[:, 1]     # P(disc)
    p_cup  = F.softmax(out_cup,  dim=1)[:, 1]     # P(cup)
    return F.relu(p_cup - p_disc).mean()

# %%
# ============================================================
# CELL 7 — Dual-Decoder U-Net (Y-Net) + SPATIAL ATTENTION (CBAM) in both decoders
# Shared encoder/bottleneck -> two decoders. After EVERY decoder stage, a CBAM
# spatial-attention block re-weights the features (focus on disc/cup region).
# Still returns (disc_logits, cup_logits), so all later cells are unchanged.
# ============================================================
class DoubleConv(nn.Module):
    """(Conv3x3 -> BN -> ReLU) x2"""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1), nn.BatchNorm2d(out_ch), nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1), nn.BatchNorm2d(out_ch), nn.ReLU(inplace=True),
        )
    def forward(self, x):
        return self.block(x)

class SpatialAttention(nn.Module):
    """CBAM spatial attention: avg+max pool ACROSS channels -> concat -> conv -> sigmoid -> multiply."""
    def __init__(self, kernel_size=7):
        super().__init__()
        self.conv = nn.Conv2d(2, 1, kernel_size, padding=kernel_size // 2, bias=False)
    def forward(self, x):
        avg_map = torch.mean(x, dim=1, keepdim=True)          # [B,1,H,W]  average over channels
        max_map, _ = torch.max(x, dim=1, keepdim=True)        # [B,1,H,W]  max over channels
        attn = torch.sigmoid(self.conv(torch.cat([avg_map, max_map], dim=1)))  # [B,1,H,W] mask
        return x * attn                                       # emphasise relevant regions

class Decoder(nn.Module):
    """One U-Net decoder branch with a CBAM spatial-attention block after each stage."""
    def __init__(self, base_ch=64, num_classes=2):
        super().__init__()
        C1, C2, C3, C4 = base_ch, base_ch*2, base_ch*4, base_ch*8
        self.up4 = nn.ConvTranspose2d(C4*2, C4, 2, stride=2); self.dec4 = DoubleConv(C4*2, C4); self.sa4 = SpatialAttention()
        self.up3 = nn.ConvTranspose2d(C4,   C3, 2, stride=2); self.dec3 = DoubleConv(C3*2, C3); self.sa3 = SpatialAttention()
        self.up2 = nn.ConvTranspose2d(C3,   C2, 2, stride=2); self.dec2 = DoubleConv(C2*2, C2); self.sa2 = SpatialAttention()
        self.up1 = nn.ConvTranspose2d(C2,   C1, 2, stride=2); self.dec1 = DoubleConv(C1*2, C1); self.sa1 = SpatialAttention()
        self.head = nn.Conv2d(C1, num_classes, 1)
    def forward(self, b, e1, e2, e3, e4):
        d4 = self.sa4(self.dec4(torch.cat([self.up4(b),  e4], 1)))   # stage 4 + spatial attention
        d3 = self.sa3(self.dec3(torch.cat([self.up3(d4), e3], 1)))   # stage 3 + spatial attention
        d2 = self.sa2(self.dec2(torch.cat([self.up2(d3), e2], 1)))   # stage 2 + spatial attention
        d1 = self.sa1(self.dec1(torch.cat([self.up1(d2), e1], 1)))   # stage 1 + spatial attention
        return self.head(d1)

class DualDecoderUNet(nn.Module):
    """Shared encoder/bottleneck + two spatial-attention decoders running in parallel."""
    def __init__(self, in_ch=3, base_ch=64, num_classes=2):
        super().__init__()
        C1, C2, C3, C4 = base_ch, base_ch*2, base_ch*4, base_ch*8
        self.enc1 = DoubleConv(in_ch, C1)
        self.enc2 = DoubleConv(C1, C2)
        self.enc3 = DoubleConv(C2, C3)
        self.enc4 = DoubleConv(C3, C4)
        self.pool = nn.MaxPool2d(2)
        self.bottleneck = DoubleConv(C4, C4*2)
        self.disc_decoder = Decoder(base_ch, num_classes)   # Pipeline 1: bg vs disc  (+ spatial attention)
        self.cup_decoder  = Decoder(base_ch, num_classes)   # Pipeline 2: bg vs cup   (+ spatial attention)
    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        b  = self.bottleneck(self.pool(e4))
        disc_logits = self.disc_decoder(b, e1, e2, e3, e4)
        cup_logits  = self.cup_decoder (b, e1, e2, e3, e4)
        return disc_logits, cup_logits

# sanity check
_m = DualDecoderUNet().to(DEVICE)
_od, _oc = _m(torch.randn(2, 3, IMG_SIZE, IMG_SIZE).to(DEVICE))
print("disc head:", _od.shape, "| cup head:", _oc.shape)
print("params:", sum(p.numel() for p in _m.parameters() if p.requires_grad))
del _m, _od, _oc
# Out:
# disc head: torch.Size([2, 2, 256, 256]) | cup head: torch.Size([2, 2, 256, 256])
# params: 43236820

# %%
# ============================================================
# CELL 8 — Training loop (dual head + containment)
# Loss per step = disc_loss + cup_loss + LAMBDA_CONTAIN * containment.
# Prints Dice of BOTH pipelines separately for BOTH train and val each epoch.
# Best checkpoint = highest mean foreground Dice = (disc_fg + cup_fg)/2 on val.
# ============================================================
def train_dual(model, train_loader, val_loader,
               num_epochs=150, patience=25, lr=1e-3,
               save_path=SAVE_PATH):
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
    criterion = CombinedLoss(2)

    history = {"train_loss": [], "val_loss": []}
    for split in ["train","val"]:
        for head in ["disc","cup"]:
            for c in range(2):
                history[f"{split}_{head}_dice_c{c}"] = []
    history["val_mean_fg"] = []

    best_mean, no_improve = 0.0, 0
    print("="*70,
          f"\nTraining Dual-Decoder U-Net + Spatial Attention (containment λ={LAMBDA_CONTAIN})\n",
          "="*70, sep="")
    for epoch in range(1, num_epochs+1):
        model.train()
        running = 0.0
        for imgs, disc_m, cup_m in train_loader:
            imgs, disc_m, cup_m = imgs.to(DEVICE), disc_m.to(DEVICE), cup_m.to(DEVICE)
            optimizer.zero_grad()
            out_disc, out_cup = model(imgs)
            loss = (criterion(out_disc, disc_m) + criterion(out_cup, cup_m)
                    + LAMBDA_CONTAIN * containment_loss(out_disc, out_cup))
            loss.backward(); optimizer.step()
            running += loss.item() * imgs.size(0)
        train_loss = running / len(train_loader.dataset)

        _,        tr_disc, tr_cup = evaluate_dual(model, train_loader, criterion)
        val_loss, va_disc, va_cup = evaluate_dual(model, val_loader,   criterion)
        scheduler.step()

        history["train_loss"].append(train_loss); history["val_loss"].append(val_loss)
        for c in range(2):
            history[f"train_disc_dice_c{c}"].append(tr_disc["dice"][c])
            history[f"train_cup_dice_c{c}"].append(tr_cup["dice"][c])
            history[f"val_disc_dice_c{c}"].append(va_disc["dice"][c])
            history[f"val_cup_dice_c{c}"].append(va_cup["dice"][c])
        mean_fg = (va_disc["dice"][1] + va_cup["dice"][1]) / 2
        history["val_mean_fg"].append(mean_fg)

        print(f"Ep {epoch:3d}/{num_epochs} | TrLoss:{train_loss:.4f} | ValLoss:{val_loss:.4f} | ValMeanFG:{mean_fg:.4f}")
        print(f"   DISC head [bg, disc] -> Train Dice:{np.round(tr_disc['dice'],3)} | Val Dice:{np.round(va_disc['dice'],3)}")
        print(f"   CUP  head [bg, cup ] -> Train Dice:{np.round(tr_cup['dice'],3)} | Val Dice:{np.round(va_cup['dice'],3)}")

        if mean_fg > best_mean:
            best_mean, no_improve = mean_fg, 0
            torch.save(model.state_dict(), save_path)
            print(f"   -> best saved (mean FG Dice = {best_mean:.4f})")
        else:
            no_improve += 1
            if no_improve >= patience:
                print(f"Early stopping at epoch {epoch}")
                break
    return history

# %%
# ============================================================
# CELL 9 — Build the model and train it
# ============================================================
model = DualDecoderUNet(in_ch=3, base_ch=64, num_classes=2).to(DEVICE)
print("Trainable params:", sum(p.numel() for p in model.parameters() if p.requires_grad))

history = train_dual(model, train_loader, val_loader,
                     num_epochs=150, patience=25, lr=1e-3,
                     save_path=SAVE_PATH)
# Out:
# Trainable params: 43236820
# ======================================================================
# Training Dual-Decoder U-Net + Spatial Attention (containment λ=0.5)
# ======================================================================
# Ep   1/150 | TrLoss:0.6708 | ValLoss:1.7475 | ValMeanFG:0.5985
#    DISC head [bg, disc] -> Train Dice:[0.809 0.921] | Val Dice:[0.286 0.828]
#    CUP  head [bg, cup ] -> Train Dice:[0.878 0.638] | Val Dice:[0.48  0.369]
#    -> best saved (mean FG Dice = 0.5985)
# Ep   2/150 | TrLoss:0.4442 | ValLoss:1.1998 | ValMeanFG:0.6619
#    DISC head [bg, disc] -> Train Dice:[0.843 0.925] | Val Dice:[0.512 0.857]
#    CUP  head [bg, cup ] -> Train Dice:[0.917 0.711] | Val Dice:[0.702 0.466]
#    -> best saved (mean FG Dice = 0.6619)
# Ep   3/150 | TrLoss:0.3610 | ValLoss:0.6647 | ValMeanFG:0.7856
#    DISC head [bg, disc] -> Train Dice:[0.874 0.948] | Val Dice:[0.634 0.88 ]
#    CUP  head [bg, cup ] -> Train Dice:[0.955 0.792] | Val Dice:[0.91  0.691]
#    -> best saved (mean FG Dice = 0.7856)
# Ep   4/150 | TrLoss:0.3257 | ValLoss:1.5395 | ValMeanFG:0.6644
#    DISC head [bg, disc] -> Train Dice:[0.873 0.946] | Val Dice:[0.537 0.861]
#    CUP  head [bg, cup ] -> Train Dice:[0.901 0.703] | Val Dice:[0.701 0.467]
# Ep   5/150 | TrLoss:0.3020 | ValLoss:0.5741 | ValMeanFG:0.8161
#    DISC head [bg, disc] -> Train Dice:[0.885 0.949] | Val Dice:[0.802 0.921]
#    CUP  head [bg, cup ] -> Train Dice:[0.957 0.823] | Val Dice:[0.914 0.712]
#    -> best saved (mean FG Dice = 0.8161)
# Ep   6/150 | TrLoss:0.2803 | ValLoss:0.5359 | ValMeanFG:0.8290
#    DISC head [bg, disc] -> Train Dice:[0.896 0.957] | Val Dice:[0.793 0.914]
#    CUP  head [bg, cup ] -> Train Dice:[0.962 0.831] | Val Dice:[0.93  0.744]
#    -> best saved (mean FG Dice = 0.8290)
# Ep   7/150 | TrLoss:0.2660 | ValLoss:0.9980 | ValMeanFG:0.7665
#    DISC head [bg, disc] -> Train Dice:[0.901 0.959] | Val Dice:[0.748 0.9  ]
#    CUP  head [bg, cup ] -> Train Dice:[0.916 0.735] | Val Dice:[0.872 0.633]
# Ep   8/150 | TrLoss:0.2566 | ValLoss:0.3973 | ValMeanFG:0.8562
#    DISC head [bg, disc] -> Train Dice:[0.896 0.959] | Val Dice:[0.843 0.93 ]
#    CUP  head [bg, cup ] -> Train Dice:[0.965 0.844] | Val Dice:[0.945 0.783]
#    -> best saved (mean FG Dice = 0.8562)
# Ep   9/150 | TrLoss:0.2518 | ValLoss:0.6016 | ValMeanFG:0.8026
#    DISC head [bg, disc] -> Train Dice:[0.903 0.961] | Val Dice:[0.814 0.922]
#    CUP  head [bg, cup ] -> Train Dice:[0.961 0.835] | Val Dice:[0.899 0.683]
# Ep  10/150 | TrLoss:0.2375 | ValLoss:1.0952 | ValMeanFG:0.7472
#    DISC head [bg, disc] -> Train Dice:[0.866 0.95 ] | Val Dice:[0.722 0.9  ]
#    CUP  head [bg, cup ] -> Train Dice:[0.951 0.81 ] | Val Dice:[0.842 0.594]
# Ep  11/150 | TrLoss:0.2386 | ValLoss:0.3661 | ValMeanFG:0.8753
#    DISC head [bg, disc] -> Train Dice:[0.913 0.963] | Val Dice:[0.852 0.932]
#    CUP  head [bg, cup ] -> Train Dice:[0.965 0.844] | Val Dice:[0.959 0.818]
#    -> best saved (mean FG Dice = 0.8753)
# Ep  12/150 | TrLoss:0.2386 | ValLoss:0.4416 | ValMeanFG:0.8582
#    DISC head [bg, disc] -> Train Dice:[0.924 0.968] | Val Dice:[0.82  0.919]
#    CUP  head [bg, cup ] -> Train Dice:[0.968 0.852] | Val Dice:[0.954 0.798]
# Ep  13/150 | TrLoss:0.2237 | ValLoss:0.6063 | ValMeanFG:0.7969
#    DISC head [bg, disc] -> Train Dice:[0.914 0.965] | Val Dice:[0.748 0.89 ]
#    CUP  head [bg, cup ] -> Train Dice:[0.961 0.797] | Val Dice:[0.945 0.704]
# Ep  14/150 | TrLoss:0.2272 | ValLoss:0.5130 | ValMeanFG:0.8351
#    DISC head [bg, disc] -> Train Dice:[0.923 0.967] | Val Dice:[0.825 0.92 ]
#    CUP  head [bg, cup ] -> Train Dice:[0.968 0.852] | Val Dice:[0.936 0.75 ]
# Ep  15/150 | TrLoss:0.2231 | ValLoss:0.7720 | ValMeanFG:0.7872
#    DISC head [bg, disc] -> Train Dice:[0.907 0.962] | Val Dice:[0.787 0.917]
#    CUP  head [bg, cup ] -> Train Dice:[0.963 0.847] | Val Dice:[0.886 0.658]
# Ep  16/150 | TrLoss:0.2204 | ValLoss:0.3941 | ValMeanFG:0.8570
#    DISC head [bg, disc] -> Train Dice:[0.912 0.964] | Val Dice:[0.864 0.937]
#    CUP  head [bg, cup ] -> Train Dice:[0.965 0.85 ] | Val Dice:[0.942 0.777]
# Ep  17/150 | TrLoss:0.2210 | ValLoss:0.4552 | ValMeanFG:0.8584
#    DISC head [bg, disc] -> Train Dice:[0.916 0.962] | Val Dice:[0.822 0.917]
#    CUP  head [bg, cup ] -> Train Dice:[0.961 0.841] | Val Dice:[0.952 0.8  ]
# Ep  18/150 | TrLoss:0.2170 | ValLoss:0.6413 | ValMeanFG:0.8331
#    DISC head [bg, disc] -> Train Dice:[0.918 0.964] | Val Dice:[0.721 0.887]
#    CUP  head [bg, cup ] -> Train Dice:[0.969 0.858] | Val Dice:[0.944 0.779]
# Ep  19/150 | TrLoss:0.2191 | ValLoss:0.4240 | ValMeanFG:0.8556
#    DISC head [bg, disc] -> Train Dice:[0.918 0.967] | Val Dice:[0.82  0.924]
#    CUP  head [bg, cup ] -> Train Dice:[0.963 0.847] | Val Dice:[0.946 0.787]
# Ep  20/150 | TrLoss:0.2145 | ValLoss:0.2776 | ValMeanFG:0.8924
#    DISC head [bg, disc] -> Train Dice:[0.928 0.969] | Val Dice:[0.889 0.942]
#    CUP  head [bg, cup ] -> Train Dice:[0.969 0.852] | Val Dice:[0.966 0.842]
#    -> best saved (mean FG Dice = 0.8924)
# Ep  21/150 | TrLoss:0.2077 | ValLoss:0.3227 | ValMeanFG:0.8834
#    DISC head [bg, disc] -> Train Dice:[0.923 0.966] | Val Dice:[0.869 0.938]
#    CUP  head [bg, cup ] -> Train Dice:[0.965 0.823] | Val Dice:[0.965 0.829]
# Ep  22/150 | TrLoss:0.2067 | ValLoss:0.3358 | ValMeanFG:0.8798
#    DISC head [bg, disc] -> Train Dice:[0.922 0.966] | Val Dice:[0.868 0.938]
#    CUP  head [bg, cup ] -> Train Dice:[0.969 0.856] | Val Dice:[0.959 0.822]
# Ep  23/150 | TrLoss:0.2088 | ValLoss:0.3367 | ValMeanFG:0.8827
#    DISC head [bg, disc] -> Train Dice:[0.926 0.97 ] | Val Dice:[0.857 0.938]
#    CUP  head [bg, cup ] -> Train Dice:[0.97  0.863] | Val Dice:[0.961 0.828]
# Ep  24/150 | TrLoss:0.2068 | ValLoss:0.3114 | ValMeanFG:0.8840
#    DISC head [bg, disc] -> Train Dice:[0.931 0.97 ] | Val Dice:[0.886 0.94 ]
#    CUP  head [bg, cup ] -> Train Dice:[0.97  0.861] | Val Dice:[0.961 0.829]
# Ep  25/150 | TrLoss:0.2034 | ValLoss:0.3405 | ValMeanFG:0.8805
#    DISC head [bg, disc] -> Train Dice:[0.926 0.97 ] | Val Dice:[0.854 0.931]
#    CUP  head [bg, cup ] -> Train Dice:[0.97  0.866] | Val Dice:[0.962 0.83 ]
# Ep  26/150 | TrLoss:0.2049 | ValLoss:0.5475 | ValMeanFG:0.8345
#    DISC head [bg, disc] -> Train Dice:[0.923 0.967] | Val Dice:[0.846 0.933]
#    CUP  head [bg, cup ] -> Train Dice:[0.968 0.859] | Val Dice:[0.926 0.736]
# Ep  27/150 | TrLoss:0.1987 | ValLoss:0.3941 | ValMeanFG:0.8561
#    DISC head [bg, disc] -> Train Dice:[0.925 0.967] | Val Dice:[0.869 0.938]
#    CUP  head [bg, cup ] -> Train Dice:[0.967 0.861] | Val Dice:[0.941 0.774]
# Ep  28/150 | TrLoss:0.1992 | ValLoss:0.3050 | ValMeanFG:0.8811
#    DISC head [bg, disc] -> Train Dice:[0.928 0.968] | Val Dice:[0.874 0.937]
#    CUP  head [bg, cup ] -> Train Dice:[0.97 0.86] | Val Dice:[0.966 0.825]
# Ep  29/150 | TrLoss:0.1983 | ValLoss:0.2800 | ValMeanFG:0.8925
#    DISC head [bg, disc] -> Train Dice:[0.935 0.973] | Val Dice:[0.89  0.947]
#    CUP  head [bg, cup ] -> Train Dice:[0.972 0.87 ] | Val Dice:[0.965 0.838]
#    -> best saved (mean FG Dice = 0.8925)
# Ep  30/150 | TrLoss:0.1931 | ValLoss:0.4221 | ValMeanFG:0.8538
#    DISC head [bg, disc] -> Train Dice:[0.936 0.973] | Val Dice:[0.86  0.931]
#    CUP  head [bg, cup ] -> Train Dice:[0.969 0.863] | Val Dice:[0.943 0.777]
# Ep  31/150 | TrLoss:0.1969 | ValLoss:0.2810 | ValMeanFG:0.8958
#    DISC head [bg, disc] -> Train Dice:[0.935 0.972] | Val Dice:[0.878 0.941]
#    CUP  head [bg, cup ] -> Train Dice:[0.97  0.855] | Val Dice:[0.97  0.851]
#    -> best saved (mean FG Dice = 0.8958)
# Ep  32/150 | TrLoss:0.1996 | ValLoss:0.2225 | ValMeanFG:0.9059
#    DISC head [bg, disc] -> Train Dice:[0.932 0.972] | Val Dice:[0.92 0.96]
#    CUP  head [bg, cup ] -> Train Dice:[0.969 0.866] | Val Dice:[0.971 0.851]
#    -> best saved (mean FG Dice = 0.9059)
# Ep  33/150 | TrLoss:0.1930 | ValLoss:0.4539 | ValMeanFG:0.8422
#    DISC head [bg, disc] -> Train Dice:[0.935 0.972] | Val Dice:[0.85  0.927]
#    CUP  head [bg, cup ] -> Train Dice:[0.968 0.865] | Val Dice:[0.935 0.757]
# Ep  34/150 | TrLoss:0.1982 | ValLoss:0.3043 | ValMeanFG:0.8905
#    DISC head [bg, disc] -> Train Dice:[0.921 0.964] | Val Dice:[0.866 0.933]
#    CUP  head [bg, cup ] -> Train Dice:[0.97  0.866] | Val Dice:[0.967 0.848]
# Ep  35/150 | TrLoss:0.2000 | ValLoss:0.2380 | ValMeanFG:0.9057
#    DISC head [bg, disc] -> Train Dice:[0.935 0.973] | Val Dice:[0.904 0.954]
#    CUP  head [bg, cup ] -> Train Dice:[0.97  0.865] | Val Dice:[0.971 0.858]
# Ep  36/150 | TrLoss:0.1913 | ValLoss:0.3190 | ValMeanFG:0.8753
#    DISC head [bg, disc] -> Train Dice:[0.935 0.972] | Val Dice:[0.882 0.942]
#    CUP  head [bg, cup ] -> Train Dice:[0.968 0.868] | Val Dice:[0.953 0.808]
# Ep  37/150 | TrLoss:0.1913 | ValLoss:0.3646 | ValMeanFG:0.8752
#    DISC head [bg, disc] -> Train Dice:[0.936 0.973] | Val Dice:[0.869 0.94 ]
#    CUP  head [bg, cup ] -> Train Dice:[0.971 0.864] | Val Dice:[0.955 0.81 ]
# Ep  38/150 | TrLoss:0.1946 | ValLoss:0.3546 | ValMeanFG:0.8677
#    DISC head [bg, disc] -> Train Dice:[0.925 0.967] | Val Dice:[0.887 0.945]
#    CUP  head [bg, cup ] -> Train Dice:[0.968 0.864] | Val Dice:[0.948 0.79 ]
# Ep  39/150 | TrLoss:0.1919 | ValLoss:0.2482 | ValMeanFG:0.9000
#    DISC head [bg, disc] -> Train Dice:[0.941 0.975] | Val Dice:[0.91  0.957]
#    CUP  head [bg, cup ] -> Train Dice:[0.971 0.872] | Val Dice:[0.965 0.843]
# Ep  40/150 | TrLoss:0.1844 | ValLoss:0.2681 | ValMeanFG:0.8928
#    DISC head [bg, disc] -> Train Dice:[0.938 0.974] | Val Dice:[0.902 0.951]
#    CUP  head [bg, cup ] -> Train Dice:[0.972 0.868] | Val Dice:[0.968 0.835]
# Ep  41/150 | TrLoss:0.1789 | ValLoss:0.4223 | ValMeanFG:0.8547
#    DISC head [bg, disc] -> Train Dice:[0.934 0.971] | Val Dice:[0.845 0.921]
#    CUP  head [bg, cup ] -> Train Dice:[0.971 0.876] | Val Dice:[0.947 0.788]
# Ep  42/150 | TrLoss:0.1819 | ValLoss:0.2754 | ValMeanFG:0.8963
#    DISC head [bg, disc] -> Train Dice:[0.941 0.975] | Val Dice:[0.894 0.946]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.872] | Val Dice:[0.967 0.846]
# Ep  43/150 | TrLoss:0.1776 | ValLoss:0.2983 | ValMeanFG:0.8855
#    DISC head [bg, disc] -> Train Dice:[0.928 0.968] | Val Dice:[0.893 0.944]
#    CUP  head [bg, cup ] -> Train Dice:[0.969 0.866] | Val Dice:[0.96  0.827]
# Ep  44/150 | TrLoss:0.1872 | ValLoss:0.2837 | ValMeanFG:0.8943
#    DISC head [bg, disc] -> Train Dice:[0.94  0.975] | Val Dice:[0.899 0.953]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.878] | Val Dice:[0.962 0.835]
# Ep  45/150 | TrLoss:0.1818 | ValLoss:0.4814 | ValMeanFG:0.8549
#    DISC head [bg, disc] -> Train Dice:[0.937 0.974] | Val Dice:[0.829 0.925]
#    CUP  head [bg, cup ] -> Train Dice:[0.972 0.875] | Val Dice:[0.945 0.785]
# Ep  46/150 | TrLoss:0.1789 | ValLoss:0.2723 | ValMeanFG:0.8916
#    DISC head [bg, disc] -> Train Dice:[0.94  0.974] | Val Dice:[0.912 0.955]
#    CUP  head [bg, cup ] -> Train Dice:[0.971 0.875] | Val Dice:[0.959 0.828]
# Ep  47/150 | TrLoss:0.1790 | ValLoss:0.3935 | ValMeanFG:0.8597
#    DISC head [bg, disc] -> Train Dice:[0.937 0.972] | Val Dice:[0.865 0.934]
#    CUP  head [bg, cup ] -> Train Dice:[0.97  0.875] | Val Dice:[0.946 0.786]
# Ep  48/150 | TrLoss:0.1767 | ValLoss:0.2809 | ValMeanFG:0.8896
#    DISC head [bg, disc] -> Train Dice:[0.943 0.975] | Val Dice:[0.904 0.952]
#    CUP  head [bg, cup ] -> Train Dice:[0.972 0.877] | Val Dice:[0.96  0.827]
# Ep  49/150 | TrLoss:0.1736 | ValLoss:0.2285 | ValMeanFG:0.9076
#    DISC head [bg, disc] -> Train Dice:[0.93  0.969] | Val Dice:[0.911 0.956]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.878] | Val Dice:[0.971 0.86 ]
#    -> best saved (mean FG Dice = 0.9076)
# Ep  50/150 | TrLoss:0.1777 | ValLoss:0.3401 | ValMeanFG:0.8838
#    DISC head [bg, disc] -> Train Dice:[0.934 0.973] | Val Dice:[0.883 0.946]
#    CUP  head [bg, cup ] -> Train Dice:[0.969 0.864] | Val Dice:[0.958 0.821]
# Ep  51/150 | TrLoss:0.1730 | ValLoss:0.2337 | ValMeanFG:0.9041
#    DISC head [bg, disc] -> Train Dice:[0.942 0.975] | Val Dice:[0.917 0.957]
#    CUP  head [bg, cup ] -> Train Dice:[0.972 0.875] | Val Dice:[0.968 0.851]
# Ep  52/150 | TrLoss:0.1870 | ValLoss:0.2357 | ValMeanFG:0.9079
#    DISC head [bg, disc] -> Train Dice:[0.937 0.973] | Val Dice:[0.91  0.953]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.877] | Val Dice:[0.971 0.863]
#    -> best saved (mean FG Dice = 0.9079)
# Ep  53/150 | TrLoss:0.1814 | ValLoss:0.2757 | ValMeanFG:0.8950
#    DISC head [bg, disc] -> Train Dice:[0.943 0.976] | Val Dice:[0.909 0.955]
#    CUP  head [bg, cup ] -> Train Dice:[0.972 0.879] | Val Dice:[0.962 0.835]
# Ep  54/150 | TrLoss:0.1778 | ValLoss:0.2685 | ValMeanFG:0.9005
#    DISC head [bg, disc] -> Train Dice:[0.941 0.975] | Val Dice:[0.902 0.951]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.873] | Val Dice:[0.967 0.85 ]
# Ep  55/150 | TrLoss:0.1733 | ValLoss:0.2307 | ValMeanFG:0.9055
#    DISC head [bg, disc] -> Train Dice:[0.939 0.974] | Val Dice:[0.913 0.954]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.879] | Val Dice:[0.971 0.857]
# Ep  56/150 | TrLoss:0.1766 | ValLoss:0.2382 | ValMeanFG:0.9078
#    DISC head [bg, disc] -> Train Dice:[0.942 0.975] | Val Dice:[0.905 0.947]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.881] | Val Dice:[0.973 0.868]
# Ep  57/150 | TrLoss:0.1736 | ValLoss:0.3419 | ValMeanFG:0.8761
#    DISC head [bg, disc] -> Train Dice:[0.941 0.976] | Val Dice:[0.899 0.952]
#    CUP  head [bg, cup ] -> Train Dice:[0.971 0.877] | Val Dice:[0.949 0.8  ]
# Ep  58/150 | TrLoss:0.1718 | ValLoss:0.2641 | ValMeanFG:0.8994
#    DISC head [bg, disc] -> Train Dice:[0.941 0.975] | Val Dice:[0.908 0.955]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.88 ] | Val Dice:[0.965 0.844]
# Ep  59/150 | TrLoss:0.1743 | ValLoss:0.2940 | ValMeanFG:0.8911
#    DISC head [bg, disc] -> Train Dice:[0.945 0.976] | Val Dice:[0.894 0.947]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.882] | Val Dice:[0.962 0.836]
# Ep  60/150 | TrLoss:0.1682 | ValLoss:0.2878 | ValMeanFG:0.8908
#    DISC head [bg, disc] -> Train Dice:[0.944 0.977] | Val Dice:[0.902 0.953]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.879] | Val Dice:[0.961 0.829]
# Ep  61/150 | TrLoss:0.1688 | ValLoss:0.2722 | ValMeanFG:0.9011
#    DISC head [bg, disc] -> Train Dice:[0.946 0.977] | Val Dice:[0.898 0.952]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.882] | Val Dice:[0.968 0.85 ]
# Ep  62/150 | TrLoss:0.1679 | ValLoss:0.2191 | ValMeanFG:0.9107
#    DISC head [bg, disc] -> Train Dice:[0.943 0.975] | Val Dice:[0.918 0.958]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.883] | Val Dice:[0.971 0.864]
#    -> best saved (mean FG Dice = 0.9107)
# Ep  63/150 | TrLoss:0.1683 | ValLoss:0.1992 | ValMeanFG:0.9143
#    DISC head [bg, disc] -> Train Dice:[0.947 0.978] | Val Dice:[0.931 0.965]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.878] | Val Dice:[0.973 0.864]
#    -> best saved (mean FG Dice = 0.9143)
# Ep  64/150 | TrLoss:0.1647 | ValLoss:0.2497 | ValMeanFG:0.9038
#    DISC head [bg, disc] -> Train Dice:[0.947 0.978] | Val Dice:[0.914 0.957]
#    CUP  head [bg, cup ] -> Train Dice:[0.973 0.885] | Val Dice:[0.967 0.85 ]
# Ep  65/150 | TrLoss:0.1634 | ValLoss:0.2059 | ValMeanFG:0.9095
#    DISC head [bg, disc] -> Train Dice:[0.946 0.977] | Val Dice:[0.931 0.965]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.881] | Val Dice:[0.972 0.854]
# Ep  66/150 | TrLoss:0.1633 | ValLoss:0.2360 | ValMeanFG:0.9074
#    DISC head [bg, disc] -> Train Dice:[0.945 0.977] | Val Dice:[0.917 0.957]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.885] | Val Dice:[0.969 0.857]
# Ep  67/150 | TrLoss:0.1626 | ValLoss:0.2457 | ValMeanFG:0.9077
#    DISC head [bg, disc] -> Train Dice:[0.947 0.977] | Val Dice:[0.905 0.954]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.888] | Val Dice:[0.97  0.862]
# Ep  68/150 | TrLoss:0.1657 | ValLoss:0.2332 | ValMeanFG:0.9106
#    DISC head [bg, disc] -> Train Dice:[0.947 0.978] | Val Dice:[0.918 0.961]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.884] | Val Dice:[0.97 0.86]
# Ep  69/150 | TrLoss:0.1667 | ValLoss:0.2770 | ValMeanFG:0.8931
#    DISC head [bg, disc] -> Train Dice:[0.946 0.977] | Val Dice:[0.904 0.951]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.886] | Val Dice:[0.962 0.835]
# Ep  70/150 | TrLoss:0.1604 | ValLoss:0.2429 | ValMeanFG:0.8983
#    DISC head [bg, disc] -> Train Dice:[0.948 0.978] | Val Dice:[0.921 0.96 ]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.887] | Val Dice:[0.962 0.837]
# Ep  71/150 | TrLoss:0.1603 | ValLoss:0.2678 | ValMeanFG:0.8922
#    DISC head [bg, disc] -> Train Dice:[0.947 0.978] | Val Dice:[0.917 0.957]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.888] | Val Dice:[0.958 0.827]
# Ep  72/150 | TrLoss:0.1595 | ValLoss:0.2119 | ValMeanFG:0.9162
#    DISC head [bg, disc] -> Train Dice:[0.949 0.978] | Val Dice:[0.92  0.957]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.883] | Val Dice:[0.975 0.876]
#    -> best saved (mean FG Dice = 0.9162)
# Ep  73/150 | TrLoss:0.1582 | ValLoss:0.3197 | ValMeanFG:0.8795
#    DISC head [bg, disc] -> Train Dice:[0.946 0.977] | Val Dice:[0.907 0.953]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.889] | Val Dice:[0.952 0.806]
# Ep  74/150 | TrLoss:0.1606 | ValLoss:0.2908 | ValMeanFG:0.8910
#    DISC head [bg, disc] -> Train Dice:[0.946 0.977] | Val Dice:[0.901 0.949]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.885] | Val Dice:[0.961 0.833]
# Ep  75/150 | TrLoss:0.1585 | ValLoss:0.1883 | ValMeanFG:0.9190
#    DISC head [bg, disc] -> Train Dice:[0.947 0.978] | Val Dice:[0.938 0.969]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.885] | Val Dice:[0.972 0.869]
#    -> best saved (mean FG Dice = 0.9190)
# Ep  76/150 | TrLoss:0.1570 | ValLoss:0.2778 | ValMeanFG:0.8968
#    DISC head [bg, disc] -> Train Dice:[0.948 0.978] | Val Dice:[0.908 0.955]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.888] | Val Dice:[0.963 0.839]
# Ep  77/150 | TrLoss:0.1535 | ValLoss:0.2270 | ValMeanFG:0.9072
#    DISC head [bg, disc] -> Train Dice:[0.948 0.978] | Val Dice:[0.924 0.962]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.888] | Val Dice:[0.968 0.852]
# Ep  78/150 | TrLoss:0.1563 | ValLoss:0.2470 | ValMeanFG:0.9062
#    DISC head [bg, disc] -> Train Dice:[0.95  0.979] | Val Dice:[0.91  0.956]
#    CUP  head [bg, cup ] -> Train Dice:[0.974 0.882] | Val Dice:[0.97  0.857]
# Ep  79/150 | TrLoss:0.1581 | ValLoss:0.2164 | ValMeanFG:0.9164
#    DISC head [bg, disc] -> Train Dice:[0.947 0.977] | Val Dice:[0.923 0.962]
#    CUP  head [bg, cup ] -> Train Dice:[0.976 0.888] | Val Dice:[0.973 0.871]
# Ep  80/150 | TrLoss:0.1560 | ValLoss:0.2101 | ValMeanFG:0.9134
#    DISC head [bg, disc] -> Train Dice:[0.949 0.978] | Val Dice:[0.924 0.961]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.89 ] | Val Dice:[0.972 0.866]
# Ep  81/150 | TrLoss:0.1572 | ValLoss:0.2424 | ValMeanFG:0.9083
#    DISC head [bg, disc] -> Train Dice:[0.949 0.978] | Val Dice:[0.912 0.954]
#    CUP  head [bg, cup ] -> Train Dice:[0.976 0.892] | Val Dice:[0.971 0.862]
# Ep  82/150 | TrLoss:0.1557 | ValLoss:0.1989 | ValMeanFG:0.9174
#    DISC head [bg, disc] -> Train Dice:[0.95  0.979] | Val Dice:[0.928 0.963]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.887] | Val Dice:[0.975 0.872]
# Ep  83/150 | TrLoss:0.1530 | ValLoss:0.1942 | ValMeanFG:0.9169
#    DISC head [bg, disc] -> Train Dice:[0.95  0.978] | Val Dice:[0.934 0.967]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.891] | Val Dice:[0.972 0.867]
# Ep  84/150 | TrLoss:0.1543 | ValLoss:0.1898 | ValMeanFG:0.9198
#    DISC head [bg, disc] -> Train Dice:[0.946 0.978] | Val Dice:[0.933 0.966]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.886] | Val Dice:[0.974 0.874]
#    -> best saved (mean FG Dice = 0.9198)
# Ep  85/150 | TrLoss:0.1583 | ValLoss:0.2302 | ValMeanFG:0.9051
#    DISC head [bg, disc] -> Train Dice:[0.951 0.979] | Val Dice:[0.917 0.956]
#    CUP  head [bg, cup ] -> Train Dice:[0.976 0.89 ] | Val Dice:[0.972 0.855]
# Ep  86/150 | TrLoss:0.1517 | ValLoss:0.2618 | ValMeanFG:0.9001
#    DISC head [bg, disc] -> Train Dice:[0.95  0.979] | Val Dice:[0.912 0.957]
#    CUP  head [bg, cup ] -> Train Dice:[0.976 0.892] | Val Dice:[0.966 0.843]
# Ep  87/150 | TrLoss:0.1493 | ValLoss:0.2144 | ValMeanFG:0.9130
#    DISC head [bg, disc] -> Train Dice:[0.948 0.978] | Val Dice:[0.928 0.963]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.886] | Val Dice:[0.971 0.863]
# Ep  88/150 | TrLoss:0.1524 | ValLoss:0.2332 | ValMeanFG:0.9011
#    DISC head [bg, disc] -> Train Dice:[0.95  0.979] | Val Dice:[0.918 0.956]
#    CUP  head [bg, cup ] -> Train Dice:[0.976 0.892] | Val Dice:[0.97  0.846]
# Ep  89/150 | TrLoss:0.1506 | ValLoss:0.2072 | ValMeanFG:0.9132
#    DISC head [bg, disc] -> Train Dice:[0.95  0.979] | Val Dice:[0.927 0.962]
#    CUP  head [bg, cup ] -> Train Dice:[0.976 0.894] | Val Dice:[0.973 0.865]
# Ep  90/150 | TrLoss:0.1482 | ValLoss:0.3198 | ValMeanFG:0.8874
#    DISC head [bg, disc] -> Train Dice:[0.952 0.98 ] | Val Dice:[0.882 0.942]
#    CUP  head [bg, cup ] -> Train Dice:[0.977 0.895] | Val Dice:[0.966 0.832]
# Ep  91/150 | TrLoss:0.1470 | ValLoss:0.1961 | ValMeanFG:0.9158
#    DISC head [bg, disc] -> Train Dice:[0.95  0.979] | Val Dice:[0.935 0.967]
#    CUP  head [bg, cup ] -> Train Dice:[0.977 0.895] | Val Dice:[0.972 0.864]
# Ep  92/150 | TrLoss:0.1472 | ValLoss:0.2376 | ValMeanFG:0.9076
#    DISC head [bg, disc] -> Train Dice:[0.952 0.98 ] | Val Dice:[0.919 0.961]
#    CUP  head [bg, cup ] -> Train Dice:[0.977 0.897] | Val Dice:[0.969 0.854]
# Ep  93/150 | TrLoss:0.1454 | ValLoss:0.2142 | ValMeanFG:0.9161
#    DISC head [bg, disc] -> Train Dice:[0.951 0.98 ] | Val Dice:[0.924 0.963]
#    CUP  head [bg, cup ] -> Train Dice:[0.976 0.895] | Val Dice:[0.972 0.869]
# Ep  94/150 | TrLoss:0.1448 | ValLoss:0.2548 | ValMeanFG:0.9084
#    DISC head [bg, disc] -> Train Dice:[0.951 0.979] | Val Dice:[0.907 0.955]
#    CUP  head [bg, cup ] -> Train Dice:[0.975 0.887] | Val Dice:[0.971 0.861]
# Ep  95/150 | TrLoss:0.1477 | ValLoss:0.2140 | ValMeanFG:0.9113
#    DISC head [bg, disc] -> Train Dice:[0.953 0.98 ] | Val Dice:[0.925 0.961]
#    CUP  head [bg, cup ] -> Train Dice:[0.977 0.897] | Val Dice:[0.973 0.861]
# Ep  96/150 | TrLoss:0.1449 | ValLoss:0.2308 | ValMeanFG:0.9088
#    DISC head [bg, disc] -> Train Dice:[0.951 0.979] | Val Dice:[0.917 0.955]
#    CUP  head [bg, cup ] -> Train Dice:[0.977 0.895] | Val Dice:[0.972 0.863]
# Ep  97/150 | TrLoss:0.1465 | ValLoss:0.2257 | ValMeanFG:0.9108
#    DISC head [bg, disc] -> Train Dice:[0.952 0.98 ] | Val Dice:[0.919 0.962]
#    CUP  head [bg, cup ] -> Train Dice:[0.977 0.895] | Val Dice:[0.972 0.86 ]
# Ep  98/150 | TrLoss:0.1455 | ValLoss:0.2045 | ValMeanFG:0.9149
#    DISC head [bg, disc] -> Train Dice:[0.952 0.98 ] | Val Dice:[0.931 0.965]
#    CUP  head [bg, cup ] -> Train Dice:[0.976 0.897] | Val Dice:[0.973 0.865]
# Ep  99/150 | TrLoss:0.1448 | ValLoss:0.2202 | ValMeanFG:0.9118
#    DISC head [bg, disc] -> Train Dice:[0.952 0.98 ] | Val Dice:[0.923 0.961]
#    CUP  head [bg, cup ] -> Train Dice:[0.977 0.899] | Val Dice:[0.971 0.862]
# Ep 100/150 | TrLoss:0.1463 | ValLoss:0.2432 | ValMeanFG:0.9048
#    DISC head [bg, disc] -> Train Dice:[0.953 0.98 ] | Val Dice:[0.921 0.962]
#    CUP  head [bg, cup ] -> Train Dice:[0.978 0.901] | Val Dice:[0.969 0.848]
# Ep 101/150 | TrLoss:0.1440 | ValLoss:0.2037 | ValMeanFG:0.9145
#    DISC head [bg, disc] -> Train Dice:[0.952 0.979] | Val Dice:[0.932 0.966]
#    CUP  head [bg, cup ] -> Train Dice:[0.978 0.899] | Val Dice:[0.973 0.862]
# Ep 102/150 | TrLoss:0.1464 | ValLoss:0.1865 | ValMeanFG:0.9162
#    DISC head [bg, disc] -> Train Dice:[0.952 0.98 ] | Val Dice:[0.939 0.97 ]
#    CUP  head [bg, cup ] -> Train Dice:[0.977 0.895] | Val Dice:[0.974 0.862]
# Ep 103/150 | TrLoss:0.1416 | ValLoss:0.2071 | ValMeanFG:0.9159
#    DISC head [bg, disc] -> Train Dice:[0.953 0.98 ] | Val Dice:[0.93  0.965]
#    CUP  head [bg, cup ] -> Train Dice:[0.978 0.9  ] | Val Dice:[0.973 0.866]
# Ep 104/150 | TrLoss:0.1442 | ValLoss:0.2084 | ValMeanFG:0.9162
#    DISC head [bg, disc] -> Train Dice:[0.953 0.98 ] | Val Dice:[0.927 0.963]
#    CUP  head [bg, cup ] -> Train Dice:[0.978 0.899] | Val Dice:[0.974 0.869]
# Ep 105/150 | TrLoss:0.1408 | ValLoss:0.2292 | ValMeanFG:0.9119
#    DISC head [bg, disc] -> Train Dice:[0.953 0.98 ] | Val Dice:[0.92  0.961]
#    CUP  head [bg, cup ] -> Train Dice:[0.978 0.902] | Val Dice:[0.971 0.863]
# Ep 106/150 | TrLoss:0.1419 | ValLoss:0.2112 | ValMeanFG:0.9172
#    DISC head [bg, disc] -> Train Dice:[0.954 0.981] | Val Dice:[0.926 0.964]
#    CUP  head [bg, cup ] -> Train Dice:[0.979 0.903] | Val Dice:[0.974 0.871]
# Ep 107/150 | TrLoss:0.1410 | ValLoss:0.2144 | ValMeanFG:0.9139
#    DISC head [bg, disc] -> Train Dice:[0.953 0.98 ] | Val Dice:[0.928 0.965]
#    CUP  head [bg, cup ] -> Train Dice:[0.978 0.903] | Val Dice:[0.971 0.863]
# Ep 108/150 | TrLoss:0.1392 | ValLoss:0.1989 | ValMeanFG:0.9176
#    DISC head [bg, disc] -> Train Dice:[0.954 0.98 ] | Val Dice:[0.931 0.966]
#    CUP  head [bg, cup ] -> Train Dice:[0.978 0.903] | Val Dice:[0.974 0.869]
# Ep 109/150 | TrLoss:0.1391 | ValLoss:0.2087 | ValMeanFG:0.9147
#    DISC head [bg, disc] -> Train Dice:[0.954 0.98 ] | Val Dice:[0.93  0.966]
#    CUP  head [bg, cup ] -> Train Dice:[0.978 0.904] | Val Dice:[0.972 0.864]
# Early stopping at epoch 109

# %%
# ============================================================
# CELL 10 — Training curves (both pipelines separately)
# ============================================================
def plot_dual_curves(history):
    fig, ax = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle("Dual-Decoder U-Net + Spatial Attention — training curves", fontsize=14)

    ax[0,0].plot(history["train_loss"], label="Train")
    ax[0,0].plot(history["val_loss"],   label="Val")
    ax[0,0].set_title("Total Loss (disc+cup+containment)"); ax[0,0].legend(); ax[0,0].set_xlabel("Epoch")

    ax[0,1].plot(history["val_disc_dice_c0"], label="bg")
    ax[0,1].plot(history["val_disc_dice_c1"], label="disc")
    ax[0,1].set_title("DISC head — Val Dice [bg, disc]"); ax[0,1].legend(); ax[0,1].set_xlabel("Epoch")

    ax[1,0].plot(history["val_cup_dice_c0"], label="bg")
    ax[1,0].plot(history["val_cup_dice_c1"], label="cup")
    ax[1,0].set_title("CUP head — Val Dice [bg, cup]"); ax[1,0].legend(); ax[1,0].set_xlabel("Epoch")

    ax[1,1].plot(history["val_mean_fg"], color="purple", label="Val mean(disc,cup) FG")
    ax[1,1].axhline(0.90, color="gray", ls="--", label="0.90 target")
    ax[1,1].set_title("Val Mean Foreground Dice"); ax[1,1].legend(); ax[1,1].set_xlabel("Epoch")

    plt.tight_layout(); plt.savefig(os.path.join(OUT_DIR, "dualunet_sa_curves.png"), dpi=100); plt.show()

plot_dual_curves(history)

# %%
# ============================================================
# CELL 11 — TEST-set evaluation (the two pipelines reported SEPARATELY)
# ============================================================
model.load_state_dict(torch.load(SAVE_PATH)); model.eval()
criterion = CombinedLoss(2)

test_loss, test_disc, test_cup = evaluate_dual(model, test_loader, criterion)

def print_pipeline(name, fg_label, m):
    print("="*55)
    print(f"{name} PIPELINE — TEST RESULTS   (classes: bg, {fg_label})")
    print("="*55)
    print(f"Accuracy : {m['accuracy']:.4f}")
    print(f"Dice     -> bg:{m['dice'][0]:.4f} | {fg_label}:{m['dice'][1]:.4f}")
    print(f"IoU      -> bg:{m['iou'][0]:.4f} | {fg_label}:{m['iou'][1]:.4f}")
    print(f"Precision-> bg:{m['precision'][0]:.4f} | {fg_label}:{m['precision'][1]:.4f}")
    print(f"Recall   -> bg:{m['recall'][0]:.4f} | {fg_label}:{m['recall'][1]:.4f}")
    print(f"F1       -> bg:{m['f1'][0]:.4f} | {fg_label}:{m['f1'][1]:.4f}")

print(f"Test total loss (disc+cup+containment): {test_loss:.4f}\n")
print_pipeline("DISC", "disc", test_disc)
print()
print_pipeline("CUP",  "cup",  test_cup)
# Out:
# Test total loss (disc+cup+containment): 0.2059
#
# =======================================================
# DISC PIPELINE — TEST RESULTS   (classes: bg, disc)
# =======================================================
# Accuracy : 0.9534
# Dice     -> bg:0.9309 | disc:0.9647
# IoU      -> bg:0.8710 | disc:0.9320
# Precision-> bg:0.9350 | disc:0.9627
# Recall   -> bg:0.9273 | disc:0.9670
# F1       -> bg:0.9309 | disc:0.9647
#
# =======================================================
# CUP PIPELINE — TEST RESULTS   (classes: bg, cup)
# =======================================================
# Accuracy : 0.9517
# Dice     -> bg:0.9705 | cup:0.8644
# IoU      -> bg:0.9428 | cup:0.7618
# Precision-> bg:0.9775 | cup:0.8362
# Recall   -> bg:0.9638 | cup:0.8977
# F1       -> bg:0.9705 | cup:0.8644

# %%
# ============================================================
# CELL 12 — Visualize predictions
# Columns: input | GT (3-class) | disc head | cup head | fused 3-class
# ============================================================
MEAN = np.array([0.485,0.456,0.406]); STD = np.array([0.229,0.224,0.225])

@torch.no_grad()
def visualize(dataset, n=5):
    model.eval()
    idxs = random.sample(range(len(dataset)), n)
    fig, ax = plt.subplots(n, 5, figsize=(18, 3.5*n))
    fig.suptitle("Input | GT | Disc head | Cup head | Fused", fontsize=13)
    for r, idx in enumerate(idxs):
        image, mask3 = dataset[idx]
        out_disc, out_cup = model(image.unsqueeze(0).to(DEVICE))
        disc_p = torch.argmax(out_disc,1)[0].cpu().numpy()
        cup_p  = torch.argmax(out_cup, 1)[0].cpu().numpy()
        fused  = disc_p.copy().astype(np.uint8); fused[(cup_p==1)&(disc_p==1)] = 2
        img_show = (image.permute(1,2,0).cpu().numpy()*STD + MEAN).clip(0,1)
        for c,(im,ttl,kw) in enumerate([
            (img_show,"Input",{}),
            (mask3.numpy(),"GT",{"cmap":"viridis","vmin":0,"vmax":2}),
            (disc_p,"Disc",{"cmap":"gray","vmin":0,"vmax":1}),
            (cup_p,"Cup",{"cmap":"gray","vmin":0,"vmax":1}),
            (fused,"Fused",{"cmap":"viridis","vmin":0,"vmax":2})]):
            ax[r,c].imshow(im, **kw); ax[r,c].set_title(ttl); ax[r,c].axis("off")
    plt.tight_layout(); plt.savefig(os.path.join(OUT_DIR, "dualunet_sa_predictions.png"), dpi=100); plt.show()

visualize(test_ds, n=5)

# %%
# ============================================================
# CELL 13 — FULL RUN SUMMARY (everything in one place)
# Param count · input dimension · best TRAIN & VAL Dice (both pipelines)
# · best mean-FG · best-checkpoint epoch · TEST metrics (disc & cup)
# · FUSED 3-class (rim, cup) on test — using CELL 12's fusion rule.
# ============================================================
model.load_state_dict(torch.load(SAVE_PATH)); model.eval()
n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

val_mean  = history["val_mean_fg"]
best_ep   = int(np.argmax(val_mean))
best_mean = val_mean[best_ep]
peak_val_disc = max(history["val_disc_dice_c1"]);  peak_val_cup = max(history["val_cup_dice_c1"])
peak_tr_disc  = max(history["train_disc_dice_c1"]); peak_tr_cup = max(history["train_cup_dice_c1"])
ckpt_val_disc = history["val_disc_dice_c1"][best_ep];  ckpt_val_cup = history["val_cup_dice_c1"][best_ep]
ckpt_tr_disc  = history["train_disc_dice_c1"][best_ep]; ckpt_tr_cup = history["train_cup_dice_c1"][best_ep]

criterion = CombinedLoss(2)
test_loss, test_disc, test_cup = evaluate_dual(model, test_loader, criterion)
test_mean_fg = (test_disc["dice"][1] + test_cup["dice"][1]) / 2

@torch.no_grad()
def fused_test_dice(dataset, smooth=1e-6):
    tp = np.zeros(3); fp = np.zeros(3); fn = np.zeros(3)
    for i in range(len(dataset)):
        image, mask3 = dataset[i]
        out_disc, out_cup = model(image.unsqueeze(0).to(DEVICE))
        disc_p = torch.argmax(out_disc, 1)[0].cpu().numpy()
        cup_p  = torch.argmax(out_cup,  1)[0].cpu().numpy()
        fused  = disc_p.copy().astype(np.uint8)
        fused[(cup_p == 1) & (disc_p == 1)] = 2
        gt = mask3.numpy()
        for c in range(3):
            p, g = (fused == c), (gt == c)
            tp[c] += np.logical_and(p, g).sum()
            fp[c] += np.logical_and(p, ~g).sum()
            fn[c] += np.logical_and(~p, g).sum()
    return (2*tp + smooth) / (2*tp + fp + fn + smooth)

fused = fused_test_dice(test_ds)
fused_rim, fused_cup = fused[1], fused[2]; fused_mean = (fused_rim + fused_cup) / 2

print("="*62)
print("  DUAL-DECODER U-NET + SPATIAL ATTENTION — FULL RUN SUMMARY")
print(f"  Input dimension : {IMG_SIZE} x {IMG_SIZE}")
print(f"  Trainable params: {n_params:,}")
print(f"  Spatial attention: ON (CBAM, both decoders, every stage) | Containment λ = {LAMBDA_CONTAIN}")
print(f"  Best checkpoint : epoch {best_ep+1}  (selected on val mean-FG)")
print("="*62)
print("  BEST VALIDATION Dice (foreground)")
print(f"    DISC pipeline  : peak {peak_val_disc:.4f}  | @best-ckpt {ckpt_val_disc:.4f}")
print(f"    CUP  pipeline  : peak {peak_val_cup:.4f}  | @best-ckpt {ckpt_val_cup:.4f}")
print(f"    MEAN(disc,cup) : best {best_mean:.4f}")
print("-"*62)
print("  BEST TRAIN Dice (foreground)")
print(f"    DISC pipeline  : peak {peak_tr_disc:.4f}  | @best-ckpt {ckpt_tr_disc:.4f}")
print(f"    CUP  pipeline  : peak {peak_tr_cup:.4f}  | @best-ckpt {ckpt_tr_cup:.4f}")
print("-"*62)
print("  TEST (best checkpoint) — pipelines reported SEPARATELY")
print(f"    DISC : Dice {test_disc['dice'][1]:.4f} | IoU {test_disc['iou'][1]:.4f} | P {test_disc['precision'][1]:.4f} | R {test_disc['recall'][1]:.4f}")
print(f"    CUP  : Dice {test_cup['dice'][1]:.4f} | IoU {test_cup['iou'][1]:.4f} | P {test_cup['precision'][1]:.4f} | R {test_cup['recall'][1]:.4f}")
print(f"    MEAN(disc,cup) Dice : {test_mean_fg:.4f}")
print("-"*62)
print("  TEST — FUSED 3-class (cup \u2286 disc):  rim=1, cup=2")
print(f"    Rim  Dice          : {fused_rim:.4f}")
print(f"    Cup  Dice          : {fused_cup:.4f}")
print(f"    MEAN(rim,cup) Dice : {fused_mean:.4f}")
print("="*62)
# Out:
# ==============================================================
#   DUAL-DECODER U-NET + SPATIAL ATTENTION — FULL RUN SUMMARY
#   Input dimension : 256 x 256
#   Trainable params: 43,236,820
#   Spatial attention: ON (CBAM, both decoders, every stage) | Containment λ = 0.5
#   Best checkpoint : epoch 84  (selected on val mean-FG)
# ==============================================================
#   BEST VALIDATION Dice (foreground)
#     DISC pipeline  : peak 0.9704  | @best-ckpt 0.9661
#     CUP  pipeline  : peak 0.8756  | @best-ckpt 0.8735
#     MEAN(disc,cup) : best 0.9198
# --------------------------------------------------------------
#   BEST TRAIN Dice (foreground)
#     DISC pipeline  : peak 0.9806  | @best-ckpt 0.9775
#     CUP  pipeline  : peak 0.9040  | @best-ckpt 0.8862
# --------------------------------------------------------------
#   TEST (best checkpoint) — pipelines reported SEPARATELY
#     DISC : Dice 0.9647 | IoU 0.9320 | P 0.9627 | R 0.9670
#     CUP  : Dice 0.8644 | IoU 0.7618 | P 0.8362 | R 0.8977
#     MEAN(disc,cup) Dice : 0.9146
# --------------------------------------------------------------
#   TEST — FUSED 3-class (cup ⊆ disc):  rim=1, cup=2
#     Rim  Dice          : 0.9028
#     Cup  Dice          : 0.8638
#     MEAN(rim,cup) Dice : 0.8833
# ==============================================================
